# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Flatten
from tensorflow.keras.optimizers import RMSprop
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import sklearn.linear_model as lm
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import EarlyStopping

# %%
dataset = pd.read_csv("bank.csv")
df = dataset.copy()
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.deposit.value_counts(normalize = True)
# Out:
# no     0.52616
# yes    0.47384
# Name: deposit, dtype: float64

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(7, 6))
sns.countplot(x= df.deposit)
plt.title('Target Variable Distribution')
plt.show()

# %%
print(df.month.value_counts(), "\n")
print(df.job.value_counts())
# Out:
# 8     2824
# 1     1519
# 5     1514
# 6     1222
# 9      943
# 0      923
# 3      776
# 10     392
# 4      344
# 11     319
# 7      276
# 2      110
# Name: month, dtype: int64
#
# 4     2566
# 1     1944
# 9     1823
# 0     1334
# 7      923
# 5      778
# 6      405
# 8      360
# 10     357
# 2      328
# 3      274
# 11      70
# Name: job, dtype: int64

# %%
labelencoder = LabelEncoder()
df["job"] = labelencoder.fit_transform(df["job"])
labelencoder = LabelEncoder()
df["marital"] = labelencoder.fit_transform(df["marital"])
labelencoder = LabelEncoder()
df["education"] = labelencoder.fit_transform(df["education"])
labelencoder = LabelEncoder()
df["default"] = labelencoder.fit_transform(df["default"])
labelencoder = LabelEncoder()
df["housing"] = labelencoder.fit_transform(df["housing"])
labelencoder = LabelEncoder()
df["loan"] = labelencoder.fit_transform(df["loan"])
labelencoder = LabelEncoder()
df["contact"] = labelencoder.fit_transform(df["contact"])
labelencoder = LabelEncoder()
df["month"] = labelencoder.fit_transform(df["month"])
labelencoder = LabelEncoder()
df["poutcome"] = labelencoder.fit_transform(df["poutcome"])
labelencoder = LabelEncoder()
df["deposit"] = labelencoder.fit_transform(df["deposit"])

# %%
def plot_correlation_map(df):

    corr = df.corr()

    s, ax = plt.subplots(figsize=(15, 20))

    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    s = sns.heatmap(corr,
                    cmap=cmap,
                    square=True,
                    cbar_kws={'shrink': .9},
                    ax=ax,
                    annot=True,
                    annot_kws={'fontsize': 12})


plot_correlation_map(df)

# %%
from itertools import cycle
import plotly.graph_objects as go

palette = cycle(["#ffd670", "#70d6ff", "#ff4d6d", "#8338ec", "#90cf8e"])
targ = df.corrwith(df['deposit'], axis=0)
val = [str(round(v, 1) * 100) + '%' for v in targ.values]
fig = go.Figure()
fig.add_trace(
    go.Bar(y=targ.index,
           x=targ.values,
           orientation='h',
           text=val,
           marker_color=next(palette)))
fig.update_layout(title="Correlation of variables with Target",
                  width=1000,
                  height=500,
                  paper_bgcolor='rgb(0,0,0,0)',
                  plot_bgcolor='rgb(0,0,0,0)')
# Out:
# <div>                            <div id="7d321485-71a2-4f65-a863-4624038ba0a6" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d321485-71a2-4f65-a863-4624038ba0a6")) {                    Plotly.newPlot(                        "7d321485-71a2-4f65-a863-4624038ba0a6",                        [{"marker":{"color":"#ffd670"},"orientation":"h","text":["0.0%","10.0%","10.0%","10.0%","-0.0%","10.0%","-20.0%","-10.0%","-20.0%","-10.0%","-0.0%","50.0%","-10.0%","20.0%","10.0%","-10.0%","100.0%"],"x":[0.03490092789028266,0.06339536016946484,0.06760991787475557,0.09594819232035244,-0.04068008708114945,0.08112858919103555,-0.20388774933788423,-0.11057998365404761,-0.249846522494145,-0.05632583922269352,-0.03712138957775911,0.45191936084258283,-0.12808084612486742,0.15159251635244853,0.13986711820078007,-0.12236884707521312,0.9999999999999999],"y":["age","job","marital","education","default","balance","housing","loan","contact","day","month","duration","campaign","pdays","previous","poutcome","deposit"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","mark ...

# %% [markdown]
# ## Preprocessing

# %%
df1 = df[df['deposit'] == 'yes']
df2 = df[df['deposit'] == 'no']

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,10))

b1 = ax[0, 0].bar(df1['day'].unique(),height = df1['day'].value_counts(),color='#000000')
b2 = ax[0, 0].bar(df2['day'].unique(),height = df2['day'].value_counts(),bottom = df1['day'].value_counts(),color = '#DC4405') 
ax[0, 0].title.set_text('Day of week')
#ax[0, 0].legend((b1[0], b2[0]), ('Yes', 'No'))
ax[0, 1].bar(df1['month'].unique(),height = df1['month'].value_counts(),color='#000000')
ax[0, 1].bar(df2['month'].unique(),height = df2['month'].value_counts(),bottom = df1['month'].value_counts(),color = '#DC4405') 
ax[0, 1].title.set_text('Month')
ax[1, 0].bar(df1['job'].unique(),height = df1['job'].value_counts(),color='#000000')
ax[1, 0].bar(df1['job'].unique(),height = df2['job'].value_counts()[df1['job'].value_counts().index],bottom = df1['job'].value_counts(),color = '#DC4405') 
ax[1, 0].title.set_text('Type of Job')
ax[1, 0].tick_params(axis='x',rotation=90)
ax[1, 1].bar(df1['education'].unique(),height = df1['education'].value_counts(),color='#000000') #row=0, col=1
ax[1, 1].bar(df1['education'].unique(),height = df2['education'].value_counts()[df1['education'].value_counts().index],bottom = df1['education'].value_counts(),color = '#DC4405') 
ax[1, 1].title.set_text('Education')
ax[1, 1].tick_params(axis='x',rotation=90)
#ax[0, 1].xticks(rotation=90)
plt.figlegend((b1[0], b2[0]), ('Yes', 'No'),loc="right",title = "Term deposit")
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(15,10))

b1 = ax[0, 0].bar(df1['marital'].unique(),height = df1['marital'].value_counts(),color='#000000')
b2 = ax[0, 0].bar(df1['marital'].unique(),height = df2['marital'].value_counts()[df1['marital'].value_counts().index],bottom = df1['marital'].value_counts(),color = '#DC4405') 
ax[0, 0].title.set_text('Marital Status')
#ax[0, 0].legend((b1[0], b2[0]), ('Yes', 'No'))
ax[0, 1].bar(df1['housing'].unique(),height = df1['housing'].value_counts(),color='#000000')
ax[0, 1].bar(df1['housing'].unique(),height = df2['housing'].value_counts()[df1['housing'].value_counts().index],bottom = df1['housing'].value_counts(),color = '#DC4405') 
ax[0, 1].title.set_text('Has housing loan')
ax[0, 2].bar(df1['loan'].unique(),height = df1['loan'].value_counts(),color='#000000')
ax[0, 2].bar(df1['loan'].unique(),height = df2['loan'].value_counts()[df1['loan'].value_counts().index],bottom = df1['loan'].value_counts(),color = '#DC4405') 
ax[0, 2].title.set_text('Has personal loan')
ax[1, 0].bar(df1['contact'].unique(),height = df1['contact'].value_counts(),color='#000000')
ax[1, 0].bar(df1['contact'].unique(),height = df2['contact'].value_counts()[df1['contact'].value_counts().index],bottom = df1['contact'].value_counts(),color = '#DC4405') 
ax[1, 0].title.set_text('Type of Contact')
ax[1, 1].bar(df1['default'].unique(),height = df1['default'].value_counts(),color='#000000')
ax[1, 1].bar(df1['default'].unique(),height = df2['default'].value_counts()[df1['default'].value_counts().index],bottom = df1['default'].value_counts(),color = '#DC4405') 
ax[1, 1].title.set_text('Has credit in default')
ax[1, 2].bar(df1['poutcome'].unique(),height = df1['poutcome'].value_counts(),color='#000000')
ax[1, 2].bar(df1['poutcome'].unique(),height = df2['poutcome'].value_counts()[df1['poutcome'].value_counts().index],bottom = df1['poutcome'].value_counts(),color = '#DC4405') 
ax[1, 2].title.set_text('Outcome of the previous marketing campaign')
plt.figlegend((b1[0], b2[0]), ('Yes', 'No'),loc="right",title = "Term deposit")
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,10))

ax[0, 0].hist(df2['age'],color = '#DC4405',alpha=0.7,bins=20, edgecolor='white') 
ax[0, 0].hist(df1['age'],color='#000000',alpha=0.5,bins=20, edgecolor='white')
ax[0, 0].title.set_text('Age')
ax[0, 1].hist(df2['duration'],color = '#DC4405',alpha=0.7, edgecolor='white') 
ax[0, 1].hist(df1['duration'],color='#000000',alpha=0.5, edgecolor='white')
ax[0, 1].title.set_text('Contact duration')
ax[1, 0].hist(df2['campaign'],color = '#DC4405',alpha=0.7, edgecolor='white') 
ax[1, 0].hist(df1['campaign'],color='#000000',alpha=0.5, edgecolor='white')
ax[1, 0].title.set_text('Number of contacts performed')
ax[1, 1].hist(df2[df2['pdays'] != 999]['pdays'],color = '#DC4405',alpha=0.7, edgecolor='white') 
ax[1, 1].hist(df1[df1['pdays'] != 999]['pdays'],color='#000000',alpha=0.5, edgecolor='white')
ax[1, 1].title.set_text('Previous contact days')
plt.figlegend((b1[0], b2[0]), ('Yes', 'No'),loc="right",title = "Term deposit")
plt.show()

# %%
predictors = df.iloc[:,0:20]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# ## Label encoding

# %%
from sklearn import preprocessing

# %%
X = df.drop(columns=["deposit"],axis=1)
y = df[["deposit"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train_norm, X_test_norm = preprocessing.normalize(X_train), preprocessing.normalize(X_test)

# %%
perp_model = lm.Perceptron()
perp_model.fit(X_train,y_train)
y_pred = perp_model.predict(X_test)
print("Accuracy: ",(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy:  0.6948342788892207
# /home/hichem-semmar/.local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
X_train_norm, X_test_norm = preprocessing.normalize(X_train), preprocessing.normalize(X_test)

# %%
batch_size = 10
num_classes = 10
epochs = 50
stop = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

model = Sequential([
    Dense(256, activation='relu', input_dim= 16),
    Dropout(0.2),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 256)               4352
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_43 (Dense)            (None, 512)               131584
#
#  dense_44 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 136,449
# Trainable params: 136,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=RMSprop(),
              loss='binary_crossentropy',
              metrics=['accuracy'])

hist = model.fit(X_train_norm,
                 y_train,
                 epochs=50,
                 batch_size=10,
                 validation_split=0.2,
                 callbacks=[])
# Out:
# Epoch 1/50
# 625/625 [==============================] - 3s 3ms/step - loss: 0.5805 - accuracy: 0.6899 - val_loss: 0.5310 - val_accuracy: 0.7505
# Epoch 2/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7437 - val_loss: 0.4991 - val_accuracy: 0.7556
# Epoch 3/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5183 - accuracy: 0.7525 - val_loss: 0.5018 - val_accuracy: 0.7562
# Epoch 4/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5114 - accuracy: 0.7536 - val_loss: 0.4785 - val_accuracy: 0.7754
# Epoch 5/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5093 - accuracy: 0.7589 - val_loss: 0.4887 - val_accuracy: 0.7684
# Epoch 6/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5044 - accuracy: 0.7582 - val_loss: 0.4761 - val_accuracy: 0.7799
# Epoch 7/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5020 - accuracy: 0.7629 - val_loss: 0.4751 - val_accuracy: 0.7786
# Epoch 8/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5001 - accuracy: 0.7651 - val_loss: 0.4709 - val_accuracy: 0.7812
# Epoch 9/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4984 - accuracy: 0.7648 - val_loss: 0.4815 - val_accuracy: 0.7793
# Epoch 10/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4984 - accuracy: 0.7648 - val_loss: 0.4810 - val_accuracy: 0.7684
# Epoch 11/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4935 - accuracy: 0.7656 - val_loss: 0.4729 - val_accuracy: 0.7869
# Epoch 12/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4944 - accuracy: 0.7662 - val_loss: 0.4884 - val_accuracy: 0.7607
# Epoch 13/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4934 - accuracy: 0.7736 - val_loss: 0.4653 - val_accuracy: 0.7767
# Epoch 14/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4919 - accuracy: 0.7669 - val_loss: 0.4651 - val_accuracy: 0.7895
# Epoch 15/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4902 - accuracy: 0.7686 - val_loss: 0.4702 - val_accuracy: 0.7812
# Epoch 16/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4901 - accuracy: 0.7720 - val_loss: 0.4940 - val_accuracy: 0.7710
# Epoch 17/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4849 - accuracy: 0.7744 - val_loss: 0.4711 - val_accuracy: 0.7812
# Epoch 18/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4912 - accuracy: 0.7715 - val_loss: 0.4904 - val_accuracy: 0.7601
# Epoch 19/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4878 - accuracy: 0.7749 - val_loss: 0.4700 - val_accuracy: 0.7876
# Epoch 20/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.4851 - accuracy: 0.7677 - val_loss: 0.4771 - val_accuracy: 0.7793
# Epoch 21/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4869 - accuracy: 0.7707 - val_loss: 0.4498 - val_accuracy: 0.7857
# Epoch 22/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4858 - accuracy: 0.7712 - val_loss: 0.4553 - val_accuracy: 0.7933
# Epoch 23/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4816 - accuracy: 0.7742 - val_loss: 0.4585 - val_accuracy: 0.7793
# Epoch 24/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4849 - accuracy: 0.7774 - val_loss: 0.4624 - val_accuracy: 0.7780
# Epoch 25/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4822 - accuracy: 0.7765 - val_loss: 0.4779 - val_accuracy: 0.7684
# Epoch 26/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4819 - accuracy: 0.7770 - val_loss: 0.4565 - val_accuracy: 0.7876
# Epoch 27/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4821 - accuracy: 0.7747 - val_loss: 0.4673 - val_accuracy: 0.7774
# Epoch 28/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4802 - accuracy: 0.7798 - val_loss: 0.4606 - val_accuracy: 0.7869
# Epoch 29/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4793 - accuracy: 0.7734 - val_loss: 0.4575 - val_accuracy: 0.7825
# Epoch 30/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4800 - accuracy: 0.7758 - val_loss: 0.4652 - val_accuracy: 0.7876
# Epoch 31/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4783 - accuracy: 0.7774 - val_loss: 0.4610 - val_accuracy: 0.7857
# Epoch 32/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4789 - accuracy: 0.7782 - val_loss: 0.4606 - val_accuracy: 0.7908
# Epoch 33/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4779 - accuracy: 0.7786 - val_loss: 0.4629 - val_accuracy: 0.7831
# Epoch 34/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4767 - accuracy: 0.7826 - val_loss: 0.4705 - val_accuracy: 0.7735
# Epoch 35/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4744 - accuracy: 0.7837 - val_loss: 0.4602 - val_accuracy: 0.7921
# Epoch 36/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4746 - accuracy: 0.7813 - val_loss: 0.4626 - val_accuracy: 0.7806
# Epoch 37/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4741 - accuracy: 0.7819 - val_loss: 0.4824 - val_accuracy: 0.7882
# Epoch 38/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4772 - accuracy: 0.7835 - val_loss: 0.4521 - val_accuracy: 0.7946
# Epoch 39/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4737 - accuracy: 0.7845 - val_loss: 0.4539 - val_accuracy: 0.7914
# Epoch 40/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4736 - accuracy: 0.7834 - val_loss: 0.4702 - val_accuracy: 0.7895
# Epoch 41/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4747 - accuracy: 0.7819 - val_loss: 0.4572 - val_accuracy: 0.7850
# Epoch 42/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4745 - accuracy: 0.7798 - val_loss: 0.4576 - val_accuracy: 0.7946
# Epoch 43/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4733 - accuracy: 0.7843 - val_loss: 0.4518 - val_accuracy: 0.7901
# Epoch 44/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4777 - accuracy: 0.7835 - val_loss: 0.4577 - val_accuracy: 0.7921
# Epoch 45/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4702 - accuracy: 0.7851 - val_loss: 0.4661 - val_accuracy: 0.7869
# Epoch 46/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4720 - accuracy: 0.7822 - val_loss: 0.4680 - val_accuracy: 0.7946
# Epoch 47/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4736 - accuracy: 0.7858 - val_loss: 0.4683 - val_accuracy: 0.7991
# Epoch 48/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4743 - accuracy: 0.7894 - val_loss: 0.4680 - val_accuracy: 0.7774
# Epoch 49/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4745 - accuracy: 0.7885 - val_loss: 0.4610 - val_accuracy: 0.7844
# Epoch 50/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4673 - accuracy: 0.7890 - val_loss: 0.4522 - val_accuracy: 0.7927

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn import metrics
predicted_labels = (model.predict(X_test_norm))
predictions = [float(round(x[0])) for x in predicted_labels]

# %%
FPR, TPR, cutoffs = metrics.roc_curve(y_test,predictions,pos_label=1) 
bp_x = FPR
bp_y = TPR

plt.plot(bp_x, bp_y, linewidth=3,
         color="blue", label=r"Curve")
plt.xlabel(r"False Positive")
plt.ylabel(r"True Positive")
plt.title(r"Title here (remove for papers)")
plt.legend(loc="lower left")
plt.show()
plt.show()

# %%
score = model.evaluate(X_test_norm, y_test, verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.7909823656082153

# %%
from sklearn.metrics import f1_score, classification_report,confusion_matrix, ConfusionMatrixDisplay
def conf_matrix(y_test, y_pred, model):
    cm = confusion_matrix(y_test, y_pred, labels=range(0,2))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(0,2))
    fig, ax = plt.subplots(figsize=(15,12))
    disp.plot(ax=ax)
    plt.show()
conf_matrix(y_test, predictions, model)

# %% [markdown]
# # Unnormalized data

# %%
hist1 = model.fit(X_train,
                 y_train,
                 epochs=50,
                 batch_size=10,
                 validation_split=0.2)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 2s 3ms/step - loss: 66.3481 - accuracy: 0.6946 - val_loss: 6.5418 - val_accuracy: 0.7837
# Epoch 2/50
# 625/625 [==============================] - 2s 3ms/step - loss: 8.1177 - accuracy: 0.7026 - val_loss: 2.5407 - val_accuracy: 0.7492
# Epoch 3/50
# 625/625 [==============================] - 2s 3ms/step - loss: 2.9559 - accuracy: 0.7138 - val_loss: 2.3090 - val_accuracy: 0.6903
# Epoch 4/50
# 625/625 [==============================] - 2s 3ms/step - loss: 1.8160 - accuracy: 0.7339 - val_loss: 1.2361 - val_accuracy: 0.7876
# Epoch 5/50
# 625/625 [==============================] - 2s 3ms/step - loss: 1.3126 - accuracy: 0.7558 - val_loss: 0.9885 - val_accuracy: 0.7959
# Epoch 6/50
# 625/625 [==============================] - 2s 3ms/step - loss: 1.1453 - accuracy: 0.7630 - val_loss: 0.8041 - val_accuracy: 0.7665
# Epoch 7/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8163 - accuracy: 0.7683 - val_loss: 0.8659 - val_accuracy: 0.7729
# Epoch 8/50
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0398 - accuracy: 0.7680 - val_loss: 0.6400 - val_accuracy: 0.7895
# Epoch 9/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8824 - accuracy: 0.7682 - val_loss: 0.8174 - val_accuracy: 0.7594
# Epoch 10/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7717 - accuracy: 0.7746 - val_loss: 0.6226 - val_accuracy: 0.7946
# Epoch 11/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7446 - accuracy: 0.7763 - val_loss: 0.7264 - val_accuracy: 0.6360
# Epoch 12/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7706 - accuracy: 0.7752 - val_loss: 0.5834 - val_accuracy: 0.7901
# Epoch 13/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7016 - accuracy: 0.7731 - val_loss: 0.6591 - val_accuracy: 0.7857
# Epoch 14/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7293 - accuracy: 0.7750 - val_loss: 0.6867 - val_accuracy: 0.7933
# Epoch 15/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6885 - accuracy: 0.7701 - val_loss: 0.5497 - val_accuracy: 0.7799
# Epoch 16/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8019 - accuracy: 0.7797 - val_loss: 0.5301 - val_accuracy: 0.7940
# Epoch 17/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.7170 - accuracy: 0.7741 - val_loss: 0.6006 - val_accuracy: 0.7946
# Epoch 18/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7634 - accuracy: 0.7837 - val_loss: 0.5872 - val_accuracy: 0.7978
# Epoch 19/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6743 - accuracy: 0.7797 - val_loss: 0.5435 - val_accuracy: 0.7901
# Epoch 20/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6419 - accuracy: 0.7806 - val_loss: 0.5525 - val_accuracy: 0.7863
# Epoch 21/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6095 - accuracy: 0.7797 - val_loss: 0.5809 - val_accuracy: 0.8023
# Epoch 22/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6794 - accuracy: 0.7805 - val_loss: 1.0043 - val_accuracy: 0.7786
# Epoch 23/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6836 - accuracy: 0.7792 - val_loss: 0.5384 - val_accuracy: 0.7601
# Epoch 24/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6715 - accuracy: 0.7803 - val_loss: 0.5602 - val_accuracy: 0.7383
# Epoch 25/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7292 - accuracy: 0.7834 - val_loss: 0.5659 - val_accuracy: 0.7780
# Epoch 26/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7326 - accuracy: 0.7808 - val_loss: 0.5047 - val_accuracy: 0.8042
# Epoch 27/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6148 - accuracy: 0.7862 - val_loss: 0.5691 - val_accuracy: 0.7473
# Epoch 28/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6707 - accuracy: 0.7920 - val_loss: 0.5924 - val_accuracy: 0.7940
# Epoch 29/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6024 - accuracy: 0.7794 - val_loss: 0.5212 - val_accuracy: 0.7914
# Epoch 30/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.6633 - accuracy: 0.7808 - val_loss: 0.5370 - val_accuracy: 0.7933
# Epoch 31/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5824 - accuracy: 0.7874 - val_loss: 0.5140 - val_accuracy: 0.8023
# Epoch 32/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.6202 - accuracy: 0.7832 - val_loss: 0.4838 - val_accuracy: 0.8049
# Epoch 33/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5979 - accuracy: 0.7888 - val_loss: 0.5148 - val_accuracy: 0.7991
# Epoch 34/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6335 - accuracy: 0.7914 - val_loss: 0.6297 - val_accuracy: 0.7908
# Epoch 35/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6184 - accuracy: 0.7850 - val_loss: 0.4880 - val_accuracy: 0.7940
# Epoch 36/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6412 - accuracy: 0.7846 - val_loss: 0.5363 - val_accuracy: 0.7837
# Epoch 37/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5875 - accuracy: 0.7874 - val_loss: 0.5514 - val_accuracy: 0.7953
# Epoch 38/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6024 - accuracy: 0.7894 - val_loss: 0.5135 - val_accuracy: 0.8004
# Epoch 39/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6193 - accuracy: 0.7842 - val_loss: 0.5495 - val_accuracy: 0.8042
# Epoch 40/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6083 - accuracy: 0.7856 - val_loss: 0.5714 - val_accuracy: 0.7754
# Epoch 41/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6001 - accuracy: 0.7896 - val_loss: 0.5258 - val_accuracy: 0.7978
# Epoch 42/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6202 - accuracy: 0.7902 - val_loss: 0.8982 - val_accuracy: 0.7933
# Epoch 43/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6195 - accuracy: 0.7864 - val_loss: 0.5757 - val_accuracy: 0.7447
# Epoch 44/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5930 - accuracy: 0.7838 - val_loss: 0.5011 - val_accuracy: 0.7978
# Epoch 45/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5873 - accuracy: 0.7906 - val_loss: 0.5520 - val_accuracy: 0.7953
# Epoch 46/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6507 - accuracy: 0.7896 - val_loss: 0.5693 - val_accuracy: 0.7761
# Epoch 47/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5872 - accuracy: 0.7888 - val_loss: 0.5183 - val_accuracy: 0.8074
# Epoch 48/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7115 - accuracy: 0.7867 - val_loss: 0.5446 - val_accuracy: 0.7684
# Epoch 49/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6901 - accuracy: 0.7885 - val_loss: 0.5433 - val_accuracy: 0.8081
# Epoch 50/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6370 - accuracy: 0.7851 - val_loss: 0.5590 - val_accuracy: 0.7889

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.7736637592315674
